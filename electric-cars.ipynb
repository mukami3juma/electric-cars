# %% [markdown]
# IMPORT LIBRARIES

# %%
# importing the pandas library
import pandas as pd
# importing the numpy library
import numpy as np

# %% [markdown]
# LOADING THE DATASET

# %%
# reading the dataset
url = 'http://bit.ly/autolib_dataset'

df = pd.read_csv(url)
df.head()
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#   Displayed comment                                 ID  ... Scheduled at  \
# ...

# %%
# checking size of the dataset
df.shape
# Out:
# (5000, 25)

# %% [markdown]
# CLEANING DATA

# %%
# checking for missing values per column
df.isnull().sum()
# Out:
# Address                   0
# Cars                      0
# Bluecar counter           0
# Utilib counter            0
# Utilib 1.4 counter        0
# Charge Slots              0
# Charging Status           0
# City                      0
# Displayed comment      4889
# ID                        0
# Kind                      0
# Geo point                 0
# Postal code               0
# Public name               0
# Rental status             0
# Scheduled at           4953
# Slots                     0
# Station type              0
# Status                    0
# Subscription status       0
# year                      0
# month                     0
# day                       0
# hour                      0
# minute                    0
# dtype: int64

# %%
# replacing missing values
df['Displayed comment'].fillna('Missing Values', inplace=True)
df['Scheduled at'].fillna('Missing Values', inplace=True)
df.head()
df.dtypes
# Out:
# Address                object
# Cars                    int64
# Bluecar counter         int64
# Utilib counter          int64
# Utilib 1.4 counter      int64
# Charge Slots            int64
# Charging Status        object
# City                   object
# Displayed comment      object
# ID                     object
# Kind                   object
# Geo point              object
# Postal code             int64
# Public name            object
# Rental status          object
# Scheduled at           object
# Slots                   int64
# Station type           object
# Status                 object
# Subscription status    object
# year                    int64
# month                   int64
# day                     int64
# hour                    int64
# minute                  int64
# dtype: object

# %% [markdown]
# Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.

# %%
# total bluecar dataset per day
df1 = df.groupby(["day"], as_index = False)["Bluecar counter"].sum()
df1
# Out:
#    day  Bluecar counter
# 0    1             1366
# 1    2             1288
# 2    3             1454
# 3    4             1351
# 4    5             1406
# 5    6             1225
# 6    7             1011
# 7    8             1198
# 8    9             1369

# %%
# total bluecar dataset per hour
df2 = df.groupby(["hour"], as_index = False)["Bluecar counter"].sum()
df2
# Out:
#     hour  Bluecar counter
# 0      0              483
# 1      1              493
# 2      2              559
# 3      3              549
# 4      4              512
# 5      5              552
# 6      6              608
# 7      7              555
# 8      8              472
# 9      9              515
# 10    10              475
# 11    11              502
# 12    12              491
# 13    13              537
# 14    14              418
# 15    15              449
# 16    16              463
# 17    17              432
# 18    18              427
# 19    19              387
# 20    20              411
# 21    21              503
# 22    22              441
# 23    23              434

# %%
# total bluecar dataset per hour and day
df3 = df.groupby(["hour","day"], as_index = False)["Bluecar counter"].sum()
df3
# Out:
#      hour  day  Bluecar counter
# 0       0    1               73
# 1       0    2               50
# 2       0    3               46
# 3       0    4               83
# 4       0    5               51
# ..    ...  ...              ...
# 208    23    4               55
# 209    23    5               44
# 210    23    7               78
# 211    23    8               45
# 212    23    9               51
#
# [213 rows x 3 columns]

# %%
max_bluecars_hr_day = df2["Bluecar counter"].max()
max_bluecars_hr_day
# Out:
# 608

# %%
# maximum bluecars in the 6th hour
df2[df2["Bluecar counter"] == max_bluecars_hr_day]
# Out:
#    hour  Bluecar counter
# 6     6              608

# %%
max_bluecars_hr_day = df3["Bluecar counter"].max()
max_bluecars_hr_day
# Out:
# 119

# %%
# maximum bluecars in the 3rd day and 13th hour
df3[df3["Bluecar counter"] == max_bluecars_hr_day]
# Out:
#      hour  day  Bluecar counter
# 117    13    3              119
